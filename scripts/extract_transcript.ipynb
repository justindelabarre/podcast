# %%
#pip install whisper
#import subprocess
#subprocess.run(["pip", "install", "faster-whisper"], check=True)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from faster_whisper import WhisperModel

model = WhisperModel("base", device="cpu", compute_type="int8")

segments, info = model.transcribe(r"C:\Users\delabarre\Documents\Podcast\N26： Building and scaling the Data team for Marketing [EGGCfZ9mp1A].webm")

with open(r"C:\Users\delabarre\Documents\Podcast\transcript.txt", "w", encoding="utf-8") as f:
    for segment in segments:
        f.write(segment.text + "\n")

print("Done!")
# Out:
# Done!
